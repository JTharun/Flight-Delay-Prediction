# %%
import pandas as pd

# %%
file1=open('/content/drive/MyDrive/finalmerge.csv')

# %%
df=pd.read_csv(file1)

# %%
df
# Out:
#          Unnamed: 0  Unnamed: 0_x  FlightDate  ...  WindChillF_y  humidity_y  time_y
# 0                 0            57  2016-01-01  ...            29          66     700
# 1                 1        219870  2016-01-01  ...            29          66     700
# 2                 2        356730  2016-01-01  ...            29          66     700
# 3                 3        334974  2016-01-01  ...            29          66     700
# 4                 4        356750  2016-01-01  ...            29          66     700
# ...             ...           ...         ...  ...           ...         ...     ...
# 1815400     1815400        453453  2017-09-18  ...            69          92    2200
# 1815401     1815401        455805  2017-09-21  ...            72          75    2200
# 1815402     1815402        456636  2017-09-22  ...            71          63    2200
# 1815403     1815403        457242  2017-09-23  ...            86          55    2100
# ...

# %%
k=[]
for i in df.ArrDelayMinutes:
  if i>=15:
      app=1      
  else:
      app=0
  k.append(app)

# %%
df['TargetDelay']=k

# %%
index = df.index

condition = df["TargetDelay"] == 1

indexlist= index[condition]


indexlist = indexlist.tolist()

# %%
dictt={}

k=0
for i in indexlist:
  
    dictt[k]= df.loc[i]
    k+=1

# %%
len(dictt)
# Out:
# 379366

# %%
l=0
for i in df["TargetDelay"]:
  if i==1:
    l+=1

# %%
l
# Out:
# 379366

# %%
final=pd.DataFrame(dictt)

# %%
final
# Out:
#                      0           1       ...      379364      379365
# Unnamed: 0                6           7  ...     1815395     1815401
# Unnamed: 0_x         356840      145879  ...      449441      455805
# FlightDate       2016-01-01  2016-01-01  ...  2017-09-13  2017-09-21
# Quarter                   1           1  ...           3           3
# Year                   2016        2016  ...        2017        2017
# Month                     1           1  ...           9           9
# DayofMonth                1           1  ...          13          21
# DepTime               745.0       759.0  ...      2345.0      2358.0
# DepDel15                1.0         1.0  ...         1.0         1.0
# CRSDepTime              700         700  ...        2200        2200
# DepDelayMinutes        40.0        35.0  ...        60.0        73.0
# OriginAirportID       14747       14747  ...       12478       12478
# DestAirportID         12889       14771  ...       12892       12892
# ...

# %%
final=final.transpose()

# %%
final
# Out:
#        Unnamed: 0 Unnamed: 0_x  FlightDate  ... humidity_y time_y TargetDelay
# 0               6       356840  2016-01-01  ...         66    700           1
# 1               7       145879  2016-01-01  ...         66    700           1
# 2              12        37814  2016-01-01  ...         81   1300           1
# 3              13          887  2016-01-01  ...         83   1300           1
# 4              36       221121  2016-01-01  ...         88   1200           1
# ...           ...          ...         ...  ...        ...    ...         ...
# 379361    1815378       414558  2017-09-08  ...         70   1800           1
# 379362    1815379       413458  2017-09-08  ...         84    600           1
# 379363    1815385       441434  2017-09-03  ...         86   2300           1
# 379364    1815395       449441  2017-09-13  ...         93   2200           1
# 379365    1815401       455805  2017-09-21  ...         75   2200           1
#
# [379366 rows x 52 columns]

# %%
final.to_csv("RegressionFullDataSet.csv")
